# %% [markdown]
# # Test with ConstantRewardEnv

# %%
# !python train_constant_reward_env.py --timesteps 5000 --logdir runs/constant_reward_env
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/nachobass/Documents/Escuela/Udesa/3er año/2do semestre/RL/Tps/Lane-detection/Agent/envs/train_constant_reward_env.py", line 9, in <module>
#     from torch.utils.tensorboard import SummaryWriter
#   File "/opt/anaconda3/envs/mldl/lib/python3.11/site-packages/torch/utils/tensorboard/__init__.py", line 12, in <module>
#     from .writer import FileWriter, SummaryWriter
#   File "/opt/anaconda3/envs/mldl/lib/python3.11/site-packages/torch/utils/tensorboard/writer.py", line 19, in <module>
# ...

# %%
# !python eval_constant_reward_env.py --weights runs/constant_reward_env/best.pt --episodes 20 --seed 42
# Out:
# Evaluating agent for 20 episodes on ConstantRewardEnv...
# Observation space: 1D (discrete)
# Action space: 1 (discrete)
# Solved threshold: 1.0 points
# --------------------------------------------------
# Episode 1: return=1.00, steps=1  SOLVED
# Episode 2: return=1.00, steps=1  SOLVED
# Episode 3: return=1.00, steps=1  SOLVED
# Episode 4: return=1.00, steps=1  SOLVED
# Episode 5: return=1.00, steps=1  SOLVED
# Episode 6: return=1.00, steps=1  SOLVED
# Episode 7: return=1.00, steps=1  SOLVED
# Episode 8: return=1.00, steps=1  SOLVED
# Episode 9: return=1.00, steps=1  SOLVED
# Episode 10: return=1.00, steps=1  SOLVED
# Episode 11: return=1.00, steps=1  SOLVED
# Episode 12: return=1.00, steps=1  SOLVED
# Episode 13: return=1.00, steps=1  SOLVED
# Episode 14: return=1.00, steps=1  SOLVED
# Episode 15: return=1.00, steps=1  SOLVED
# Episode 16: return=1.00, steps=1  SOLVED
# Episode 17: return=1.00, steps=1  SOLVED
# Episode 18: return=1.00, steps=1  SOLVED
# ...

# %% [markdown]
# # Test with RandomObsBinaryRewardEnv

# %%
# !python train_random_obs_env.py --timesteps 20000 --logdir runs/random_obs_ppo_clip --seed 42
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/nachobass/Documents/Escuela/Udesa/3er año/2do semestre/RL/Tps/Lane-detection/Agent/envs/train_random_obs_env.py", line 9, in <module>
#     from torch.utils.tensorboard import SummaryWriter
#   File "/opt/anaconda3/envs/mldl/lib/python3.11/site-packages/torch/utils/tensorboard/__init__.py", line 12, in <module>
#     from .writer import FileWriter, SummaryWriter
#   File "/opt/anaconda3/envs/mldl/lib/python3.11/site-packages/torch/utils/tensorboard/writer.py", line 19, in <module>
# ...

# %%
# !python eval_random_obs_env.py --weights runs/random_obs_ppo_clip/best.pt --episodes 20 --seed 42
# Out:
# Evaluating agent for 20 episodes on RandomObsBinaryRewardEnv...
# Observation space: 1D (discrete)
# Action space: 1 (discrete)
# Solved threshold: 1.0 points
#   - RandomObsBinaryRewardEnv: Reward = observation (-1 or 1), terminates immediately
#   - Agent should get positive rewards (obs=1) to be considered solved
# --------------------------------------------------
# Episode 1: return=-1.00, steps=1
# Episode 2: return=1.00, steps=1  SOLVED
# Episode 3: return=1.00, steps=1  SOLVED
# Episode 4: return=-1.00, steps=1
# Episode 5: return=1.00, steps=1  SOLVED
# Episode 6: return=-1.00, steps=1
# Episode 7: return=-1.00, steps=1
# Episode 8: return=1.00, steps=1  SOLVED
# Episode 9: return=-1.00, steps=1
# Episode 10: return=1.00, steps=1  SOLVED
# Episode 11: return=-1.00, steps=1
# Episode 12: return=-1.00, steps=1
# Episode 13: return=1.00, steps=1  SOLVED
# Episode 14: return=-1.00, steps=1
# Episode 15: return=-1.00, steps=1
# Episode 16: return=-1.00, steps=1
# ...

# %% [markdown]
# # Test with TwoStepDelayedRewardEnv

# %%
# !python train_two_step_delayed_env.py --timesteps 20000 --logdir runs/two_step_delayed_ppo_clip --seed 42
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/nachobass/Documents/Escuela/Udesa/3er año/2do semestre/RL/Tps/Lane-detection/Agent/envs/train_two_step_delayed_env.py", line 9, in <module>
#     from torch.utils.tensorboard import SummaryWriter
#   File "/opt/anaconda3/envs/mldl/lib/python3.11/site-packages/torch/utils/tensorboard/__init__.py", line 12, in <module>
#     from .writer import FileWriter, SummaryWriter
#   File "/opt/anaconda3/envs/mldl/lib/python3.11/site-packages/torch/utils/tensorboard/writer.py", line 19, in <module>
# ...

# %%
# !python eval_two_step_delayed_env.py --weights runs/two_step_delayed_ppo_clip/best.pt --episodes 20 --seed 42
# Out:
# Evaluating agent for 20 episodes on TwoStepDelayedRewardEnv...
# Observation space: 1D (discrete)
# Action space: 1 (discrete)
# Solved threshold: 1.0 points
#   - TwoStepDelayedRewardEnv: Episode takes 2 steps
#   - Step 0: obs=0, reward=0, not terminated
#   - Step 1: obs=1, reward=1, terminated
#   - Agent must continue through step 0 to get delayed reward at step 1
# --------------------------------------------------
# Episode 1: return=1.00, steps=2  SOLVED
# Episode 2: return=1.00, steps=2  SOLVED
# Episode 3: return=1.00, steps=2  SOLVED
# Episode 4: return=1.00, steps=2  SOLVED
# Episode 5: return=1.00, steps=2  SOLVED
# Episode 6: return=1.00, steps=2  SOLVED
# Episode 7: return=1.00, steps=2  SOLVED
# Episode 8: return=1.00, steps=2  SOLVED
# Episode 9: return=1.00, steps=2  SOLVED
# Episode 10: return=1.00, steps=2  SOLVED
# Episode 11: return=1.00, steps=2  SOLVED
# Episode 12: return=1.00, steps=2  SOLVED
# Episode 13: return=1.00, steps=2  SOLVED
# ...

# %% [markdown]
# # Test with CartPole

# %%
# !python train_cartpole_ppo.py --timesteps 100000 --logdir runs/cartpole_ppo_clip
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/nachobass/Documents/Escuela/Udesa/3er año/2do semestre/RL/Tps/Lane-detection/Agent/envs/train_cartpole_ppo.py", line 9, in <module>
#     from torch.utils.tensorboard import SummaryWriter
#   File "/opt/anaconda3/envs/mldl/lib/python3.11/site-packages/torch/utils/tensorboard/__init__.py", line 12, in <module>
#     from .writer import FileWriter, SummaryWriter
#   File "/opt/anaconda3/envs/mldl/lib/python3.11/site-packages/torch/utils/tensorboard/writer.py", line 19, in <module>
# ...

# %%
# !python eval_cartpole_ppo.py --weights runs/cartpole_ppo_clip/final.pt --episodes 10
# Out:
# Evaluating agent for 10 episodes...
# Episode 1: return=500.00, steps=500
# Episode 2: return=500.00, steps=500
# Episode 3: return=500.00, steps=500
# Episode 4: return=500.00, steps=500
# Episode 5: return=500.00, steps=500
# Episode 6: return=500.00, steps=500
# Episode 7: return=500.00, steps=500
# Episode 8: return=500.00, steps=500
# Episode 9: return=500.00, steps=500
# Episode 10: return=500.00, steps=500
#
# ...
# Evaluation Results (10 episodes):
#   Mean Return: 500.00 ± 0.00
#   Mean Episode Length: 500.00 ± 0.00
#   Min Return: 500.00
#   Max Return: 500.00
# ...

# %%
# !python eval_cartpole_ppo.py --weights runs/cartpole_ppo_clip/final.pt --episodes 10 --render
# Out:
# /opt/anaconda3/envs/mldl/lib/python3.11/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# Evaluating agent for 10 episodes...
# Episode 1: return=500.00, steps=500
# Episode 2: return=500.00, steps=500
# Episode 3: return=500.00, steps=500
# Episode 4: return=500.00, steps=500
# Episode 5: return=500.00, steps=500
# Episode 6: return=500.00, steps=500
# Episode 7: return=500.00, steps=500
# Episode 8: return=500.00, steps=500
# Episode 9: return=500.00, steps=500
# Episode 10: return=500.00, steps=500
#
# ...
# Evaluation Results (10 episodes):
#   Mean Return: 500.00 ± 0.00
#   Mean Episode Length: 500.00 ± 0.00
#   Min Return: 500.00
#   Max Return: 500.00
# ...

# %% [markdown]
# # Test with BipedalWalker

# %%
# !python train_bipedalwalker_ppo.py --timesteps 10000000 --logdir runs/bipedalwalker_ppo_clip
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/nachobass/Documents/Escuela/Udesa/3er año/2do semestre/RL/Tps/Lane-detection/Agent/envs/train_bipedalwalker_ppo.py", line 8, in <module>
#     from torch.utils.tensorboard import SummaryWriter
#   File "/opt/anaconda3/envs/mldl/lib/python3.11/site-packages/torch/utils/tensorboard/__init__.py", line 12, in <module>
#     from .writer import FileWriter, SummaryWriter
#   File "/opt/anaconda3/envs/mldl/lib/python3.11/site-packages/torch/utils/tensorboard/writer.py", line 19, in <module>
# ...

# %%
# !python eval_bipedalwalker_ppo.py --weights runs/bipedalwalker_ppo_clip/final.pt --episodes 10
# Out:
# /opt/anaconda3/envs/mldl/lib/python3.11/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# Evaluating agent for 10 episodes on BipedalWalker-v3...
# Observation space: 24D
# Action space: 4D (continuous)
# Solved threshold: 270.0 points
# --------------------------------------------------
# Episode 1: return=282.59, steps=835  SOLVED
# Episode 2: return=284.62, steps=817  SOLVED
# Episode 3: return=284.48, steps=820  SOLVED
# Episode 4: return=286.68, steps=816  SOLVED
# Episode 5: return=285.10, steps=824  SOLVED
# Episode 6: return=289.10, steps=782  SOLVED
# Episode 7: return=284.64, steps=828  SOLVED
# Episode 8: return=289.23, steps=775  SOLVED
# Episode 9: return=287.53, steps=794  SOLVED
# ...

# %%
# !python eval_bipedalwalker_ppo.py --weights runs/bipedalwalker_ppo_clip/final.pt --episodes 10 --render
# Out:
# /opt/anaconda3/envs/mldl/lib/python3.11/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# Evaluating agent for 10 episodes on BipedalWalker-v3...
# Observation space: 24D
# Action space: 4D (continuous)
# Solved threshold: 270.0 points
# --------------------------------------------------
# Episode 1: return=284.47, steps=825  SOLVED
# Episode 2: return=289.85, steps=774  SOLVED
# Episode 3: return=287.09, steps=790  SOLVED
# Episode 4: return=287.69, steps=790  SOLVED
# Episode 5: return=286.04, steps=816  SOLVED
# Episode 6: return=285.09, steps=818  SOLVED
# Episode 7: return=284.99, steps=828  SOLVED
# Episode 8: return=287.35, steps=795  SOLVED
# Episode 9: return=289.13, steps=784  SOLVED
# ...

# %% [markdown]
# # Test with MountainCar

# %%
# !python train_mountain_car_ppo.py --timesteps 10000000 --logdir runs/mountain_car_ppo_clip
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/nachobass/Documents/Escuela/Udesa/3er año/2do semestre/RL/Tps/Lane-detection/Agent/envs/train_mountain_car_ppo.py", line 9, in <module>
#     from torch.utils.tensorboard import SummaryWriter
#   File "/opt/anaconda3/envs/mldl/lib/python3.11/site-packages/torch/utils/tensorboard/__init__.py", line 12, in <module>
#     from .writer import FileWriter, SummaryWriter
#   File "/opt/anaconda3/envs/mldl/lib/python3.11/site-packages/torch/utils/tensorboard/writer.py", line 19, in <module>
# ...

# %%
# !python eval_mountain_car_ppo.py --weights runs/mountain_car_ppo_clip/final.pt --episodes 10
# Out:
# Evaluating agent for 10 episodes on MountainCarContinuous-v0...
# Observation space: 2D
# Action space: 1D (continuous)
# Solved criteria: Reach the goal (terminated=True)
# --------------------------------------------------
# Episode 1: return=26.10, steps=739 SOLVED
# Episode 2: return=-99.90, steps=999
# Episode 3: return=65.10, steps=349 SOLVED
# Episode 4: return=20.50, steps=795 SOLVED
# Episode 5: return=25.50, steps=745 SOLVED
# Episode 6: return=38.10, steps=619 SOLVED
# Episode 7: return=-99.90, steps=999
# Episode 8: return=-99.90, steps=999
# Episode 9: return=-99.90, steps=999
# Episode 10: return=-99.90, steps=999
#
# ...
# Evaluation Results (10 episodes):
#   Mean Return: -32.42 ± 68.43
#   Mean Episode Length: 824.20 ± 208.59
#   Min Return: -99.90
#   Max Return: 65.10
#
# Solved Status:
#   Solved episodes: 5 / 10 (50.0%)
#   Average solved return: 35.06
#   Average solved steps: 649.40
# ...

# %%
# !python eval_mountain_car_ppo.py --weights runs/mountain_car_ppo_clip/final.pt --episodes 10 --render
# Out:
# /opt/anaconda3/envs/mldl/lib/python3.11/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# Evaluating agent for 10 episodes on MountainCarContinuous-v0...
# Observation space: 2D
# Action space: 1D (continuous)
# Solved criteria: Reach the goal (terminated=True)
# --------------------------------------------------
# Episode 1: return=-99.87, steps=999
# Episode 2: return=-99.90, steps=999
# Episode 3: return=42.12, steps=579 SOLVED
# Episode 4: return=51.70, steps=483 SOLVED
# Episode 5: return=-99.90, steps=999
# Episode 6: return=50.60, steps=494 SOLVED
# Episode 7: return=58.20, steps=418 SOLVED
# Episode 8: return=-99.90, steps=999
# Episode 9: return=-99.90, steps=999
# ...

# %% [markdown]
# # Test with CartPole Stable Baselines 3

# %%
# !python train_cartpole_stable.py --timesteps 100000 --logdir runs/cartpole_sb3_ppo
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/nachobass/Documents/Escuela/Udesa/3er año/2do semestre/RL/Tps/Lane-detection/Agent/envs/train_cartpole_stable.py", line 9, in <module>
#     from stable_baselines3 import PPO
#   File "/opt/anaconda3/envs/mldl/lib/python3.11/site-packages/stable_baselines3/__init__.py", line 3, in <module>
#     from stable_baselines3.a2c import A2C
#   File "/opt/anaconda3/envs/mldl/lib/python3.11/site-packages/stable_baselines3/a2c/__init__.py", line 1, in <module>
# ...

# %%
# !python eval_cartpole_stable.py --weights runs/cartpole_sb3_ppo/final_model.zip --episodes 10
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/nachobass/Documents/Escuela/Udesa/3er año/2do semestre/RL/Tps/Lane-detection/Agent/envs/eval_cartpole_stable.py", line 5, in <module>
#     from stable_baselines3 import PPO
#   File "/opt/anaconda3/envs/mldl/lib/python3.11/site-packages/stable_baselines3/__init__.py", line 3, in <module>
#     from stable_baselines3.a2c import A2C
#   File "/opt/anaconda3/envs/mldl/lib/python3.11/site-packages/stable_baselines3/a2c/__init__.py", line 1, in <module>
# ...

# %%
# !python eval_cartpole_stable.py --weights runs/cartpole_sb3_ppo/final_model.zip --episodes 10 --render
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/nachobass/Documents/Escuela/Udesa/3er año/2do semestre/RL/Tps/Lane-detection/Agent/envs/eval_cartpole_stable.py", line 5, in <module>
#     from stable_baselines3 import PPO
#   File "/opt/anaconda3/envs/mldl/lib/python3.11/site-packages/stable_baselines3/__init__.py", line 3, in <module>
#     from stable_baselines3.a2c import A2C
#   File "/opt/anaconda3/envs/mldl/lib/python3.11/site-packages/stable_baselines3/a2c/__init__.py", line 1, in <module>
# ...

# %% [markdown]
# # Test with BipedalWalker Stable Baselines 3

# %%
# !python train_bipedalwalker_stable.py --timesteps 10000000 --logdir runs/bipedalwalker_sb3_ppo
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/nachobass/Documents/Escuela/Udesa/3er año/2do semestre/RL/Tps/Lane-detection/Agent/envs/train_bipedalwalker_stable.py", line 9, in <module>
#     from stable_baselines3 import PPO
#   File "/opt/anaconda3/envs/mldl/lib/python3.11/site-packages/stable_baselines3/__init__.py", line 3, in <module>
#     from stable_baselines3.a2c import A2C
#   File "/opt/anaconda3/envs/mldl/lib/python3.11/site-packages/stable_baselines3/a2c/__init__.py", line 1, in <module>
# ...

# %%
# !python eval_bipedalwalker_stable.py --weights runs/bipedalwalker_sb3_ppo/final_model.zip --episodes 10
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/nachobass/Documents/Escuela/Udesa/3er año/2do semestre/RL/Tps/Lane-detection/Agent/envs/eval_bipedalwalker_stable.py", line 5, in <module>
#     from stable_baselines3 import PPO
#   File "/opt/anaconda3/envs/mldl/lib/python3.11/site-packages/stable_baselines3/__init__.py", line 3, in <module>
#     from stable_baselines3.a2c import A2C
#   File "/opt/anaconda3/envs/mldl/lib/python3.11/site-packages/stable_baselines3/a2c/__init__.py", line 1, in <module>
# ...

# %%
# !python eval_bipedalwalker_stable.py --weights runs/bipedalwalker_sb3_ppo/final_model.zip --episodes 10 --render
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/nachobass/Documents/Escuela/Udesa/3er año/2do semestre/RL/Tps/Lane-detection/Agent/envs/eval_bipedalwalker_stable.py", line 5, in <module>
#     from stable_baselines3 import PPO
#   File "/opt/anaconda3/envs/mldl/lib/python3.11/site-packages/stable_baselines3/__init__.py", line 3, in <module>
#     from stable_baselines3.a2c import A2C
#   File "/opt/anaconda3/envs/mldl/lib/python3.11/site-packages/stable_baselines3/a2c/__init__.py", line 1, in <module>
# ...

# %% [markdown]
# # Test with MountainCar Stable Baselines 3

# %%
# !python train_mountain_car_stable.py --timesteps 10000000 --logdir runs/mountain_car_sb3_ppo
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/nachobass/Documents/Escuela/Udesa/3er año/2do semestre/RL/Tps/Lane-detection/Agent/envs/train_mountain_car_stable.py", line 9, in <module>
#     from stable_baselines3 import PPO
#   File "/opt/anaconda3/envs/mldl/lib/python3.11/site-packages/stable_baselines3/__init__.py", line 3, in <module>
#     from stable_baselines3.a2c import A2C
#   File "/opt/anaconda3/envs/mldl/lib/python3.11/site-packages/stable_baselines3/a2c/__init__.py", line 1, in <module>
# ...

# %%
# !python eval_mountain_car_stable.py --weights runs/mountain_car_sb3_ppo/final_model.zip --episodes 10
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/nachobass/Documents/Escuela/Udesa/3er año/2do semestre/RL/Tps/Lane-detection/Agent/envs/eval_mountain_car_stable.py", line 5, in <module>
#     from stable_baselines3 import PPO
#   File "/opt/anaconda3/envs/mldl/lib/python3.11/site-packages/stable_baselines3/__init__.py", line 3, in <module>
#     from stable_baselines3.a2c import A2C
#   File "/opt/anaconda3/envs/mldl/lib/python3.11/site-packages/stable_baselines3/a2c/__init__.py", line 1, in <module>
# ...

# %%
# !python eval_mountain_car_stable.py --weights runs/mountain_car_sb3_ppo/final_model.zip --episodes 10 --render
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/nachobass/Documents/Escuela/Udesa/3er año/2do semestre/RL/Tps/Lane-detection/Agent/envs/eval_mountain_car_stable.py", line 5, in <module>
#     from stable_baselines3 import PPO
#   File "/opt/anaconda3/envs/mldl/lib/python3.11/site-packages/stable_baselines3/__init__.py", line 3, in <module>
#     from stable_baselines3.a2c import A2C
#   File "/opt/anaconda3/envs/mldl/lib/python3.11/site-packages/stable_baselines3/a2c/__init__.py", line 1, in <module>
# ...
